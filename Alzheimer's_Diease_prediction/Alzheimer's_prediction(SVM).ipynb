# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import validation_curve
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("oasis_longitudinal.csv")

# %%
data.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  NaN  23.0  0.5  1678  0.736  1.046
# 3  NaN  28.0  0.5  1738  0.713  1.010
# 4  NaN  22.0  0.5  1698  0.701  1.034

# %%
data = data.drop(['MRI ID', 'Visit', 'Hand'], axis=1)

# %%
data.head()
# Out:
#   Subject ID        Group  MR Delay M/F  Age  EDUC  SES  MMSE  CDR  eTIV  \
# 0  OAS2_0001  Nondemented         0   M   87    14  2.0  27.0  0.0  1987
# 1  OAS2_0001  Nondemented       457   M   88    14  2.0  30.0  0.0  2004
# 2  OAS2_0002     Demented         0   M   75    12  NaN  23.0  0.5  1678
# 3  OAS2_0002     Demented       560   M   76    12  NaN  28.0  0.5  1738
# 4  OAS2_0002     Demented      1895   M   80    12  NaN  22.0  0.5  1698
#
#     nWBV    ASF
# 0  0.696  0.883
# 1  0.681  0.876
# 2  0.736  1.046
# 3  0.713  1.010
# 4  0.701  1.034

# %%
# Check missing values by each column
pd.isnull(data).sum() 
# The column, SES has 8 missing values
# Out:
# Subject ID     0
# Group          0
# MR Delay       0
# M/F            0
# Age            0
# EDUC           0
# SES           19
# MMSE           2
# CDR            0
# eTIV           0
# nWBV           0
# ASF            0
# dtype: int64

# %%
#data.fillna(data.mean(), inplace=True)
df_dropna = data.dropna(axis=0, how='any')

# %%
pd.isnull(df_dropna).sum()
# Out:
# Subject ID    0
# Group         0
# MR Delay      0
# M/F           0
# Age           0
# EDUC          0
# SES           0
# MMSE          0
# CDR           0
# eTIV          0
# nWBV          0
# ASF           0
# dtype: int64

# %%
#data.MMSE.astype(int)
#data.SES.astype(int)

# %%
data.columns
# Out:
# Index(['Subject ID', 'Group', 'MR Delay', 'M/F', 'Age', 'EDUC', 'SES', 'MMSE',
#        'CDR', 'eTIV', 'nWBV', 'ASF'],
#       dtype='object')

# %%
#data['Group'] = data['Group'].map({"Demented":1,"Nondemented":0})

# %%
df_dropna['M/F'] = df_dropna['M/F'].replace(['F','M'], [0,1])
df_dropna['Group'] = df_dropna['Group'].replace(['Converted'], ['Demented'])
df_dropna['Group'] = df_dropna['Group'].replace(['Demented', 'Nondemented'], [1,0])
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
x = df_dropna[['M/F', 'Age', 'EDUC', 'SES', 'MMSE', 'eTIV', 'nWBV', 'ASF']]
y = df_dropna['Group']

# %%
from sklearn.preprocessing import scale
X = scale(x)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by the scale function.

# %%
df_dropna
# Out:
#     Subject ID  Group  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV  \
# 0    OAS2_0001      0         0    1   87    14  2.0  27.0  0.0  1987  0.696
# 1    OAS2_0001      0       457    1   88    14  2.0  30.0  0.0  2004  0.681
# 5    OAS2_0004      0         0    0   88    18  3.0  28.0  0.0  1215  0.710
# 6    OAS2_0004      0       538    0   90    18  3.0  27.0  0.0  1200  0.718
# 7    OAS2_0005      0         0    1   80    12  4.0  28.0  0.0  1689  0.712
# 8    OAS2_0005      0      1010    1   83    12  4.0  29.0  0.5  1701  0.711
# 9    OAS2_0005      0      1603    1   85    12  4.0  30.0  0.0  1699  0.705
# 13   OAS2_0008      0         0    0   93    14  2.0  30.0  0.0  1272  0.698
# 14   OAS2_0008      0       742    0   95    14  2.0  29.0  0.0  1257  0.703
# 15   OAS2_0009      1         0    1   68    12  2.0  27.0  0.5  1457  0.806
# 16   OAS2_0009      1       576    1   69    12  2.0  24.0  0.5  1480  0.791
# 17   OAS2_0010      1         0    0   66    12  3.0  30.0  0.5  1447  0.769
# 18   OAS2_0010      1       854    0   68    12  3.0  29.0  0.5  1482  0.752
# 19   OAS2_0012      0         0    0   78    16  2.0  29.0  0.0  1333  0.748
# 20   OAS2_0012      0       730    0   80    16  2.0  29.0  0.0  1323  0.738
# 21   OAS2_0012      0      1598    0   83    16  2.0  29.0  0.0  1323  0.718
# 22   OAS2_0013      0         0    0   81    12  4.0  30.0  0.0  1230  0.715
# 23   OAS2_0013      0       643    0   82    12  4.0  30.0  0.0  1212  0.720
# 24   OAS2_0013      0      1456    0   85    12  4.0  29.0  0.0  1225  0.710
# 25   OAS2_0014      1         0    1   76    16  3.0  21.0  0.5  1602  0.697
# 26   OAS2_0014      1       504    1   77    16  3.0  16.0  1.0  1590  0.696
# 27   OAS2_0016      1         0    1   88     8  4.0  25.0  0.5  1651  0.660
# 28   OAS2_0016      1       707    1   90     8  4.0  23.0  0.5  1668  0.646
# 29   OAS2_0017      0         0    1   80    12  3.0  29.0  0.0  1783  0.752
# 30   OAS2_0017      0       617    1   81    12  3.0  27.0  0.5  1814  0.759
# 31   OAS2_0017      0      1861    1   85    12  3.0  30.0  0.0  1820  0.755
# 32   OAS2_0017      0      2400    1   86    12  3.0  27.0  0.0  1813  0.761
# 33   OAS2_0018      1         0    0   87    14  1.0  30.0  0.0  1406  0.715
# 34   OAS2_0018      1       489    0   88    14  1.0  29.0  0.0  1398  0.713
# 35   OAS2_0018      1      1933    0   92    14  1.0  27.0  0.5  1423  0.696
# ..         ...    ...       ...  ...  ...   ...  ...   ...  ...   ...    ...
# 338  OAS2_0172      1         0    1   75    16  1.0  30.0  0.5  1891  0.709
# 339  OAS2_0172      1      1212    1   79    16  1.0  29.0  0.5  1899  0.700
# 340  OAS2_0174      0         0    1   60    12  4.0  30.0  0.0  1379  0.806
# 341  OAS2_0174      0       695    1   62    12  4.0  30.0  0.0  1378  0.795
# 342  OAS2_0174      0      1555    1   64    12  4.0  30.0  0.0  1370  0.794
# 343  OAS2_0175      1         0    1   70    16  4.0  26.0  0.5  1796  0.742
# 344  OAS2_0175      1       700    1   72    16  4.0  28.0  0.5  1796  0.732
# 345  OAS2_0175      1      1343    1   73    16  4.0  28.0  0.5  1803  0.731
# 346  OAS2_0176      1         0    1   84    16  2.0  30.0  0.0  1404  0.710
# 347  OAS2_0176      1       774    1   87    16  2.0  30.0  0.0  1398  0.696
# 348  OAS2_0176      1      1631    1   89    16  2.0  30.0  0.5  1408  0.679
# 349  OAS2_0177      0         0    1   68    14  3.0  26.0  0.0  1444  0.778
# 350  OAS2_0177      0       665    1   70    14  3.0  28.0  0.0  1510  0.770
# 351  OAS2_0178      0         0    0   89    14  2.0  29.0  0.0  1509  0.756
# 352  OAS2_0178      0       600    0   90    14  2.0  28.0  0.0  1495  0.746
# 353  OAS2_0178      0      1447    0   93    14  2.0  30.0  0.0  1488  0.735
# 354  OAS2_0179      1         0    1   79    20  1.0  26.0  0.5  1548  0.711
# 355  OAS2_0179      1       652    1   81    20  1.0  26.0  0.5  1556  0.691
# 361  OAS2_0183      0         0    0   66    13  2.0  30.0  0.0  1495  0.746
# 362  OAS2_0183      0       182    0   66    13  2.0  30.0  0.0  1506  0.740
# 363  OAS2_0183      0       732    0   68    13  2.0  30.0  0.0  1506  0.740
# 364  OAS2_0183      0      2107    0   72    13  2.0  30.0  0.0  1510  0.723
# 365  OAS2_0184      1         0    0   72    16  3.0  24.0  0.5  1354  0.733
# 366  OAS2_0184      1       553    0   73    16  3.0  21.0  1.0  1351  0.708
# 367  OAS2_0185      1         0    1   80    16  1.0  28.0  0.5  1704  0.711
# 368  OAS2_0185      1       842    1   82    16  1.0  28.0  0.5  1693  0.694
# 369  OAS2_0185      1      2297    1   86    16  1.0  26.0  0.5  1688  0.675
# 370  OAS2_0186      0         0    0   61    13  2.0  30.0  0.0  1319  0.801
# 371  OAS2_0186      0       763    0   63    13  2.0  30.0  0.0  1327  0.796
# 372  OAS2_0186      0      1608    0   65    13  2.0  30.0  0.0  1333  0.801
#
#        ASF
# 0    0.883
# 1    0.876
# 5    1.444
# 6    1.462
# 7    1.039
# 8    1.032
# 9    1.033
# 13   1.380
# 14   1.396
# 15   1.205
# 16   1.186
# 17   1.213
# 18   1.184
# 19   1.316
# 20   1.326
# 21   1.327
# 22   1.427
# 23   1.448
# 24   1.433
# 25   1.096
# 26   1.104
# 27   1.063
# 28   1.052
# 29   0.985
# 30   0.968
# 31   0.964
# 32   0.968
# 33   1.248
# 34   1.255
# 35   1.234
# ..     ...
# 338  0.928
# 339  0.924
# 340  1.273
# 341  1.274
# 342  1.281
# 343  0.977
# 344  0.977
# 345  0.973
# 346  1.250
# 347  1.255
# 348  1.246
# 349  1.216
# 350  1.162
# 351  1.163
# 352  1.174
# 353  1.179
# 354  1.134
# 355  1.128
# 361  1.174
# 362  1.165
# 363  1.165
# 364  1.162
# 365  1.296
# 366  1.299
# 367  1.030
# 368  1.037
# 369  1.040
# 370  1.331
# 371  1.323
# 372  1.317
#
# [354 rows x 12 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 3)

# %%
# confirm that splitting also has similar distribution of spam and ham 
# emails
print(y_train.mean())
print(y_test.mean())
# Out:
# 0.46153846153846156
# 0.4672897196261682

# %%
# Model building

# instantiate an object of class SVC()
# note that we are using cost C=1
model = SVC(C = 1)

# fit
model.fit(X_train, y_train)

# predict
y_pred = model.predict(X_test)
# Out:
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
from sklearn import metrics
metrics.confusion_matrix(y_true=y_test, y_pred=y_pred)
# Out:
# array([[52,  5],
#        [14, 36]])

# %%
# print other metrics

# accuracy
print("accuracy", metrics.accuracy_score(y_test, y_pred))

# precision
print("precision", metrics.precision_score(y_test, y_pred))

# recall/sensitivity
print("recall", metrics.recall_score(y_test, y_pred))
# Out:
# accuracy 0.822429906542056
# precision 0.8780487804878049
# recall 0.72

# %%
# creating a KFold object with 5 splits 
folds = KFold(n_splits = 5, shuffle = True, random_state = 3)

# instantiating a model with cost=1
model = SVC(C = 1)

# %%
cv_results = cross_val_score(model, X_train, y_train, cv = folds, scoring = 'accuracy')
# Out:
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
# print 5 accuracies obtained from the 5 folds
print(cv_results)
print("mean accuracy = {}".format(cv_results.mean()))
# Out:
# [0.78       0.76       0.81632653 0.79591837 0.7755102 ]
# mean accuracy = 0.7855510204081633

# %%
# specify range of parameters (C) as a list
params = {"C": [0.1, 1, 10, 100, 1000]}

model = SVC()

# set up grid search scheme
# note that we are still using the 5 fold CV scheme we set up earlier
model_cv = GridSearchCV(estimator = model, param_grid = params, 
                        scoring= 'accuracy', 
                        cv = folds, 
                        verbose = 1,
                       return_train_score=True)

# %%
# fit the model - it will fit 5 folds across all values of C
model_cv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    0.2s finished
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# GridSearchCV(cv=KFold(n_splits=5, random_state=3, shuffle=True),
#        error_score='raise-deprecating',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'C': [0.1, 1, 10, 100, 1000]}, pre_dispatch='2*n_jobs',
#        refit=True, return_train_score=True, scoring='accuracy', verbose=1)

# %%
best_score = model_cv.best_score_
best_C = model_cv.best_params_['C']

print(" The highest test accuracy is {0} at C = {1}".format(best_score, best_C))
# Out:
#  The highest test accuracy is 0.8259109311740891 at C = 100

# %%
# model with the best value of C
model = SVC(C=best_C)

# fit
model.fit(X_train, y_train)

# predict
y_pred = model.predict(X_test)
# Out:
# /home/saiful/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
# metrics
# print other metrics

# accuracy
print("accuracy", metrics.accuracy_score(y_test, y_pred))

# precision
print("precision", metrics.precision_score(y_test, y_pred))

# recall/sensitivity
print("recall", metrics.recall_score(y_test, y_pred))
# Out:
# accuracy 0.8785046728971962
# precision 0.8363636363636363
# recall 0.92
